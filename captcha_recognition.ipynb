# %% [markdown]
# # Import Library

# %%
import cv2
import pandas
import seaborn
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
import tensorflow as tf

# %% [markdown]
# # Convert Gambar ke Sampel

# %%
path = 'input/'

# %% [markdown]
# ### Fungsi image preprocessing

# %%
def t_img (img) :
    return cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 145, 0)

def c_img (img) :
    return cv2.morphologyEx(img, cv2.MORPH_CLOSE, np.ones((5,2), np.uint8))

def d_img (img) :
    return cv2.dilate(img, np.ones((2,2), np.uint8), iterations = 1)

def b_img (img) :
    return cv2.GaussianBlur(img, (1,1), 0)

# %%
import os
from PIL import Image
from keras.preprocessing.image import img_to_array, ImageDataGenerator

# %% [markdown]
# ### Mengubah gambar menjadi array
# Masing-masing gambar akan mengalami proses preprocessing yang menghasilkan output 5 karakter. Masing-masing 5 karakter tersebut akan diambil nilainya dalam array dan masuk ke variabel X dan nama dari karakter tersebut akan masuk ke variabel Y.

# %%
X = []
y = []

for image in os.listdir(path) :
    
    if image[6:] != 'png' :
        continue
    
    img = cv2.imread(os.path.join(path, image), cv2.IMREAD_GRAYSCALE)
    
    img = t_img(img)
    img = c_img(img)
    img = d_img(img)
    img = b_img(img)
    
    image_list = [img[10:50, 30:50], img[10:50, 50:70], img[10:50, 70:90], img[10:50, 90:110], img[10:50, 110:130]]
    
    for i in range(5) :
        X.append(img_to_array(Image.fromarray(image_list[i])))
        y.append(image[i])
X = np.array(X)
y = np.array(y)

# %%
print(X.shape)
print(y.shape)
# Out:
# (5200, 40, 20, 1)
# (5200,)

# %% [markdown]
# Dari proses ini menghasilkan 5200 karakter dengan dimensi masing-masing karakter 40x20x1.

# %% [markdown]
# # Data Wrangling
# ### Scale b/w 0 and 1

# %%
X /= 255.0

# %% [markdown]
# ### Melihat sampel karakter

# %%
plt.figure(figsize = (20,5))
for i in range(10) :
    plt.subplot(1,10,i+1)
    plt.imshow(tf.squeeze(X[i]), 'gray')
    plt.title('Label is ' + str(y[i]))
plt.plot()
# Out:
# []

# %% [markdown]
# ### Melihat jumlah masing-masing karakter

# %%
temp = set(y)
for t in temp :
    print('Occurance count of ' + t + ' : ' + str(len(y[y == t])))
# Out:
# Occurance count of 3 : 267
# Occurance count of 8 : 264
# Occurance count of b : 240
# Occurance count of 5 : 281
# Occurance count of e : 235
# Occurance count of w : 235
# Occurance count of d : 259
# Occurance count of 7 : 258
# Occurance count of 4 : 284
# Occurance count of m : 275
# Occurance count of f : 271
# Occurance count of g : 271
# Occurance count of c : 262
# Occurance count of y : 232
# Occurance count of x : 264
# Occurance count of 6 : 259
# Occurance count of p : 253
# Occurance count of n : 525
# Occurance count of 2 : 265

# %%
temp_df = pandas.DataFrame({'labels' : [t for t in temp], 'Count' : [len(y[y==t]) for t in temp]})

# %% [markdown]
# ### Grafik persebaran karakter

# %%
plt.figure(figsize = (20,7))
seaborn.barplot(x = 'labels', y = 'Count', data = temp_df, palette = 'Blues_d')
plt.title('Label distribution in CAPTCHAS', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Label distribution in CAPTCHAS')

# %% [markdown]
# ### One hot encoding
# One hot encoding adalah salah satu metode konversi data untuk mempersiapkannya untuk suatu algoritma dan mendapatkan prediksi yang lebih baik. (Mengubah data kategorikal menjadi data numerikal)

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

y_combine = LabelEncoder().fit_transform(y)
y_one_hot = OneHotEncoder(sparse = False).fit_transform(y_combine.reshape(len(y_combine),1))

# %%
print('letter 2 : ' + str(y[1]))
print('label : ' + str(y_combine[1]))
print('Count : ' + str(len(y_combine[y_combine == y_combine[1]])))
# Out:
# letter 2 : 2
# label : 0
# Count : 265

# %%
info = {y_combine[i] : y[i] for i in range(len(y))}
dict(sorted(info.items(), key=lambda x:int(x[0])))
# Out:
# {0: '2',
#  1: '3',
#  2: '4',
#  3: '5',
#  4: '6',
#  5: '7',
#  6: '8',
#  7: 'b',
#  8: 'c',
#  9: 'd',
#  10: 'e',
#  11: 'f',
#  12: 'g',
#  13: 'm',
#  14: 'n',
#  15: 'p',
#  16: 'w',
#  17: 'x',
#  18: 'y'}

# %% [markdown]
# ### Bentuk data setelah dilakukan encoding

# %%
print(X.shape)
print(y_one_hot.shape)
# Out:
# (5200, 40, 20, 1)
# (5200, 19)

# %% [markdown]
# # Splitting Data

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_one_hot, test_size = 0.2, random_state = 1)

# %% [markdown]
# ### Grafik persebaran Test Set

# %%
y_temp = np.argmax(y_test, axis = 1)

# %%
temp = set(y_temp)
temp_df = pandas.DataFrame({'labels' : [info[t] for t in temp], 'Count' : [len(y_temp[y_temp == t]) for t in temp]})

# %%
plt.figure(figsize = (20,7))
seaborn.barplot(x = 'labels', y = 'Count', data = temp_df, palette = 'Blues_d')
plt.title('Label distribution in test set', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Label distribution in test set')

# %% [markdown]
# # CNN Model

# %%
from keras.models import Sequential 
from keras.layers import Dense
from keras.layers import Conv2D
from keras.layers import Flatten
from keras.layers import MaxPooling2D
from keras.layers import BatchNormalization

from keras.layers import Dropout
from keras.layers import Input

# %% [markdown]
# ### Bentuk Train Set Data

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (4160, 40, 20, 1)
# (4160, 19)

# %% [markdown]
# ### Bentuk Test Set Data

# %%
print(X_test.shape)
print(y_test.shape)
# Out:
# (1040, 40, 20, 1)
# (1040, 19)

# %% [markdown]
# ### Data Augmentation
# Data Augmentation adalah teknik yang digunakan untuk menambah jumlah data dengan menambahkan salinan yang sedikit dimodifikasi dari data yang sudah ada atau data sintetis yang baru dibuat dari data yang ada.

# %%
traingen = ImageDataGenerator(rotation_range = 5, width_shift_range = [-2,2])
traingen.fit(X_train)

# %%
train_set = traingen.flow(X_train, y_train)

# %%
trainX, trainy = train_set.next()

# %%
plt.figure(figsize = (20,20))

hi = 32
lo = 0

for i in range(25) :
    plt.subplot(5,5,i+1)
    x = np.random.randint(lo, hi)
    plt.imshow(tf.squeeze(trainX[x]), 'gray')
    plt.title('Label is ' + str(info[np.argmax(trainy[x])]))
plt.show()

# %%
def conv_layer (filterx) :
  
  model = Sequential()
  
  model.add(Conv2D(filterx, (3,3), padding = 'same', activation = 'relu'))
  model.add(BatchNormalization())
  model.add(Dropout(0.2))
  model.add(MaxPooling2D(pool_size = (2,2), padding = 'same'))
  
  return model

# %%
def dens_layer (hiddenx) :
  
  model = Sequential()
  
  model.add(Dense(hiddenx, activation = 'relu'))
  model.add(BatchNormalization())
  model.add(Dropout(0.2))
  
  return model

# %%
def cnn (filter1, filter2, filter3, hidden1, hidden2) :
  
  model = Sequential()
  model.add(Input((40, 20, 1,)))
  
  model.add(conv_layer(filter1))
  model.add(conv_layer(filter2))
  model.add(conv_layer(filter3))
  
  model.add(Flatten())
  model.add(dens_layer(hidden1))
  model.add(dens_layer(hidden2))
  
  model.add(Dense(19, activation = 'softmax'))
  
  model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
  
  return model

# %% [markdown]
# ### Model Training
# Membuat CNN model dengan arsitektur : <br>
# <b>Input -> [[Conv2D->relu] -> Dropout -> MaxPool2D]*3 -> Flatten -> [Dense -> Dropout]*2 -> Output</b>

# %%
model = cnn(128, 32, 16, 32, 32)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 20, 10, 128)       1792
#
#  sequential_2 (Sequential)   (None, 10, 5, 32)         37024
#
#  sequential_3 (Sequential)   (None, 5, 3, 16)          4688
#
#  flatten (Flatten)           (None, 240)               0
#
#  sequential_4 (Sequential)   (None, 32)                7840
#
#  sequential_5 (Sequential)   (None, 32)                1184
#
#  dense_2 (Dense)             (None, 19)                627
#
# =================================================================
# Total params: 53,155
# Trainable params: 52,675
# Non-trainable params: 480
# _________________________________________________________________

# %% [markdown]
# ### ModelCheckpoint dan ReduceLROnPlateau
# ModelCheckpoint untuk mempertahankan model berkinerja terbaik (dalam hal loss), dan ReduceLROnPlateau untuk mengurangi pembelajaran jika model berhenti meningkat.

# %%
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
checkp = ModelCheckpoint('./result_model.h5', monitor = 'val_loss', verbose = 1, save_best_only = True)

# %%
reduce = ReduceLROnPlateau(monitor = 'val_loss', patience = 20, verbose = 1)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (4160, 40, 20, 1)
# (4160, 19)

# %%
history = model.fit(traingen.flow(X_train, y_train, batch_size = 32), validation_data = (X_test, y_test), epochs = 100, steps_per_epoch = len(X_train)/32, callbacks = [checkp])
# Out:
# Epoch 1/100
# 130/130 [==============================] - ETA: 0s - loss: 2.7462 - accuracy: 0.1882
# Epoch 1: val_loss improved from inf to 2.97779, saving model to .\result_model.h5
# 130/130 [==============================] - 47s 342ms/step - loss: 2.7462 - accuracy: 0.1882 - val_loss: 2.9778 - val_accuracy: 0.0577
# Epoch 2/100
# 130/130 [==============================] - ETA: 0s - loss: 1.9242 - accuracy: 0.4195
# Epoch 2: val_loss did not improve from 2.97779
# 130/130 [==============================] - 43s 330ms/step - loss: 1.9242 - accuracy: 0.4195 - val_loss: 3.1549 - val_accuracy: 0.0654
# Epoch 3/100
# 130/130 [==============================] - ETA: 0s - loss: 1.5613 - accuracy: 0.5442
# Epoch 3: val_loss improved from 2.97779 to 2.95124, saving model to .\result_model.h5
# 130/130 [==============================] - 47s 365ms/step - loss: 1.5613 - accuracy: 0.5442 - val_loss: 2.9512 - val_accuracy: 0.1231
# Epoch 4/100
# 130/130 [==============================] - ETA: 0s - loss: 1.3312 - accuracy: 0.6178
# Epoch 4: val_loss improved from 2.95124 to 1.98052, saving model to .\result_model.h5
100
# 130/130 [==============================] - ETA: 0s - loss: 0.3806 - accuracy: 0.8880
# Epoch 90: val_loss did not improve from 0.40022
# 130/130 [==============================] - 36s 278ms/step - loss: 0.3806 - accuracy: 0.8880 - val_loss: 0.4255 - val_accuracy: 0.8846
# Epoch 91/100
# 130/130 [==============================] - ETA: 0s - loss: 0.3611 - accuracy: 0.8935
# Epoch 91: val_loss did not improve from 0.40022
# 130/130 [==============================] - 36s 279ms/step - loss: 0.3611 - accuracy: 0.8935 - val_loss: 0.4207 - val_accuracy: 0.8904
# Epoch 92/100
# 130/130 [==============================] - ETA: 0s - loss: 0.3673 - accuracy: 0.8894
# Epoch 92: val_loss did not improve from 0.40022
# 130/130 [==============================] - 36s 280ms/step - loss: 0.3673 - accuracy: 0.8894 - val_loss: 0.4355 - val_accuracy: 0.8846
# Epoch 93/100
# 130/130 [==============================] - ETA: 0s - loss: 0.3706 - accuracy: 0.8858
# Epoch 93: val_loss did not improve from 0.40022
# 130/130 [==============================] - 37s 281ms/step - loss: 0.3706 - accuracy: 0.8858 - val_loss: 0.4977 - val_accuracy: 0.8673
# Epoch 94/100
# 130/130 [==============================] - ETA: 0s - loss: 0.3766 - accuracy: 0.8906
# Epoch 94: val_loss did not improve from 0.40022
# 130/130 [==============================] - 40s 311ms/step - loss: 0.3766 - accuracy: 0.8906 - val_loss: 0.4494 - val_accuracy: 0.8760
# Epoch 95/100
# 130/130 [==============================] - ETA: 0s - loss: 0.3600 - accuracy: 0.8877
# Epoch 95: val_loss did not improve from 0.40022
# 130/130 [==============================] - 42s 320ms/step - loss: 0.3600 - accuracy: 0.8877 - val_loss: 0.4142 - val_accuracy: 0.8894
# Epoch 96/100
# 130/130 [==============================] - ETA: 0s - loss: 0.3657 - accuracy: 0.8892
# Epoch 96: val_loss did not improve from 0.40022
# 130/130 [==============================] - 41s 318ms/step - loss: 0.3657 - accuracy: 0.8892 - val_loss: 0.4341 - val_accuracy: 0.8798
# Epoch 97/100
# 130/130 [==============================] - ETA: 0s - loss: 0.3689 - accuracy: 0.8877
# Epoch 97: val_loss did not improve from 0.40022
# 130/130 [==============================] - 44s 341ms/step - loss: 0.3689 - accuracy: 0.8877 - val_loss: 0.4371 - val_accuracy: 0.8788
# Epoch 98/100
# 130/130 [==============================] - ETA: 0s - loss: 0.3680 - accuracy: 0.8897
# Epoch 98: val_loss did not improve from 0.40022
# 130/130 [==============================] - 48s 370ms/step - loss: 0.3680 - accuracy: 0.8897 - val_loss: 0.4240 - val_accuracy: 0.8837
# Epoch 99/100
# 130/130 [==============================] - ETA: 0s - loss: 0.3695 - accuracy: 0.8909
# Epoch 99: val_loss did not improve from 0.40022
# 130/130 [==============================] - 43s 328ms/step - loss: 0.3695 - accuracy: 0.8909 - val_loss: 0.4594 - val_accuracy: 0.8760
# Epoch 100/100
# 130/130 [==============================] - ETA: 0s - loss: 0.3716 - accuracy: 0.8882
# Epoch 100: val_loss did not improve from 0.40022
# 130/130 [==============================] - 44s 342ms/step - loss: 0.3716 - accuracy: 0.8882 - val_loss: 0.4149 - val_accuracy: 0.8923

# %%
plt.figure(figsize = (20,10))
plt.subplot(2,1,1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('Epochs')
plt.ylabel('Losses')
plt.legend(['train loss','val loss'])
plt.title('Loss function berdasarkan epochs')

plt.subplot(2,1,2)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['train acc' , 'val acc'])
plt.title('Model accuracy berdasarkan Epoch')
# Out:
# Text(0.5, 1.0, 'Model accuracy berdasarkan Epoch')

# %% [markdown]
# # Model Evaluation

# %%
from keras.models import load_model

# %% [markdown]
# ### Import model terbaik yang telah disimpan

# %%
model = load_model('./result_model.h5')

# %%
pred = model.predict(X_test)

# %%
pred = np.argmax(pred, axis = 1)
yres = np.argmax(y_test,axis= 1)

# %%
from sklearn.metrics import accuracy_score, classification_report

# %%
target_name = []
for i in sorted(info) :
  target_name.append(info[i])
    
target_name
# Out:
# ['2',
#  '3',
#  '4',
#  '5',
#  '6',
#  '7',
#  '8',
#  'b',
#  'c',
#  'd',
#  'e',
#  'f',
#  'g',
#  'm',
#  'n',
#  'p',
#  'w',
#  'x',
#  'y']

# %%
print('Accuracy : ' + str(accuracy_score(yres, pred)))
print(classification_report(yres, pred, target_names = target_name))
# Out:
# Accuracy : 0.8923076923076924
#               precision    recall  f1-score   support
#
#            2       0.92      0.95      0.93        58
#            3       1.00      0.93      0.96        57
#            4       0.87      0.98      0.92        54
#            5       0.91      0.93      0.92        54
#            6       0.93      0.90      0.92        62
#            7       0.93      0.93      0.93        56
#            8       0.98      0.95      0.96        55
#            b       0.98      0.98      0.98        42
#            c       0.90      0.94      0.92        47
#            d       0.90      0.92      0.91        50
#            e       0.90      0.83      0.86        42
#            f       0.86      0.96      0.91        46
#            g       0.94      0.98      0.96        50
#            m       0.81      0.41      0.54        61
#            n       0.69      0.94      0.80       102
#            p       0.92      0.90      0.91        52
#            w       0.90      0.83      0.86        46
#            x       0.98      0.88      0.93        57
#            y       0.95      0.86      0.90        49
#
#     accuracy                           0.89      1040
#    macro avg       0.91      0.89      0.90      1040
# weighted avg       0.90      0.89      0.89      1040

# %% [markdown]
# ### Confusion Matrix

# %%
import itertools
from sklearn.metrics import confusion_matrix

# %%
label = dict(sorted(info.items(), key=lambda x:int(x[0])))
y_label = []
for i in range(19):
  y_label.append(label[i])

# %%
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    plt.figure(figsize = (20,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j], horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
# menghitung confusion matrix
confusion_mtx = confusion_matrix(yres, pred) 

# plot confusion matrix
plot_confusion_matrix(confusion_mtx, classes = y_label)

# %% [markdown]
# # Testing Model

# %%
def input_predict (img_path) :
    
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    
    plt.imshow(img, 'gray')
    plt.axis('off')
    plt.show()
    
    img = t_img(img)
    img = c_img(img)
    img = d_img(img)
    img = b_img(img)
    
    image_list = [img[10:50, 30:50], img[10:50, 50:70], img[10:50, 70:90], img[10:50, 90:110], img[10:50, 110:130]]
    
    plt.imshow(img, 'gray')
    plt.axis('off')
    plt.show()
    Xdemo = []
    for i in range(5) :
        Xdemo.append(img_to_array(Image.fromarray(image_list[i])))
    
    Xdemo = np.array(Xdemo)
    Xdemo/= 255.0
    
    ydemo = model.predict(Xdemo)
    ydemo = np.argmax(ydemo, axis = 1)
    
    print("Predicted Captcha : ", end="")
    for res in ydemo :
        print(info[res], end="")
    print()
    
    print("Real Captcha : ", end="")
    print(img_path[-9:])
    print()

# %%
input_predict('input/2g783.png')
input_predict('input/2fxgd.png')
input_predict('input/3g2w6.png')
input_predict('input/88bgx.png')
input_predict('input/53mn8.png')
# Out:
# Predicted Captcha : 2g783
# True Captcha : 2g783.png
# Predicted Captcha : 2fxgd
# True Captcha : 2fxgd.png
# Predicted Captcha : 3g2wd
# True Captcha : 3g2w6.png
# Predicted Captcha : 88bgx
# True Captcha : 88bgx.png
# Predicted Captcha : 53nm8
# True Captcha : 53mn8.png
